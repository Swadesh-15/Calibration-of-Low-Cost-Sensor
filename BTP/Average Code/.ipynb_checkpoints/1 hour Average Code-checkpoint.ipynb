# %%
from csv import reader
from csv import writer
import datetime

'''
Input sheet

1st row
date time pm1 pm2.5 pm10

2nd row to ....
data

Output sheet
1st row
date time_slot avg_pm1 avg_pm2.5 avg_pm10

2nd row to ....
data
'''

# Reading the input csv file 

def fun_time_slot(csv_time):
    # getting the hour
    csv_time_ls = csv_time.split(":")
    if len(csv_time_ls[0])>2:
        csv_time_ls[0] = csv_time_ls[0][:2]
        # print(csv_time_ls[0])
    #print(csv_time_ls)
    if datetime.time(0,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(1,0):
        return "SLOT-1"
    elif datetime.time(1,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(2,0):
        return "SLOT-2"
    elif datetime.time(2,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(3,0):
        return "SLOT-3"
    elif datetime.time(3,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(4,0):
        return "SLOT-4"
    elif datetime.time(4,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(5,0):
        return "SLOT-5"
    elif datetime.time(5,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(6,0):
        return "SLOT-6"
    elif datetime.time(6,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(7,0):
        return "SLOT-7"
    elif datetime.time(7,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(8,0):
        return "SLOT-8"
    elif datetime.time(8,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(9,0):
        return "SLOT-9"
    elif datetime.time(9,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(10,0):
        return "SLOT-10"
    elif datetime.time(10,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(11,0):
        return "SLOT-11"
    elif datetime.time(11,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(12,0):
        return "SLOT-12"
    elif datetime.time(12,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(13,0):
        return "SLOT-13"
    elif datetime.time(13,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(14,0):
        return "SLOT-14"
    elif datetime.time(14,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(15,0):
        return "SLOT-15"
    elif datetime.time(15,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(16,0):
        return "SLOT-16"
    elif datetime.time(16,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(17,0):
        return "SLOT-17"
    elif datetime.time(17,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(18,0):
        return "SLOT-18"
    elif datetime.time(18,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(19,0):
        return "SLOT-19"
    elif datetime.time(19,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(20,0):
        return "SLOT-20"
    elif datetime.time(20,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(21,0):
        return "SLOT-21"
    elif datetime.time(21,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(22,0):
        return "SLOT-22"
    elif datetime.time(22,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(23,0):
        return "SLOT-23"
    else:
        return "SLOT-24"
    
csv_data = []
with open("alphasense data.csv") as read_obj:
    row_no = 0
    csv_reader = reader(read_obj)
    for rows in csv_reader:
        if row_no>=1:
            csv_data.append(rows)
        row_no+=1
    read_obj.close()

# removing the empty rows
empty_rows_count=0
for rows in csv_data:
    if rows[0]=="":
        rows.clear()
        empty_rows_count+=1
print("removing empty rows -> ",empty_rows_count)
csv_data = list(filter(None,csv_data))
# print(csv_data)
output_data = []
initial_field = ["Date","Slot No.","AVG PM1","AVG PM2.5","AVG PM10"]
output_data.append(initial_field)
current_date = csv_data[0][0]    
time_slot_1_pm1=[]
time_slot_1_pm25=[]
time_slot_1_pm10=[]
time_slot_2_pm1=[]
time_slot_2_pm25=[]
time_slot_2_pm10=[]
time_slot_3_pm1=[]
time_slot_3_pm25=[]
time_slot_3_pm10=[]
time_slot_4_pm1=[]
time_slot_4_pm25=[]
time_slot_4_pm10=[]
time_slot_5_pm1=[]
time_slot_5_pm25=[]
time_slot_5_pm10=[]
time_slot_6_pm1=[]
time_slot_6_pm25=[]
time_slot_6_pm10=[]
time_slot_7_pm1=[]
time_slot_7_pm25=[]
time_slot_7_pm10=[]
time_slot_8_pm1=[]
time_slot_8_pm25=[]
time_slot_8_pm10=[]
time_slot_9_pm1=[]
time_slot_9_pm25=[]
time_slot_9_pm10=[]
time_slot_10_pm1=[]
time_slot_10_pm25=[]
time_slot_10_pm10=[]
time_slot_11_pm1=[]
time_slot_11_pm25=[]
time_slot_11_pm10=[]
time_slot_12_pm1=[]
time_slot_12_pm25=[]
time_slot_12_pm10=[]
time_slot_13_pm1=[]
time_slot_13_pm25=[]
time_slot_13_pm10=[]
time_slot_14_pm1=[]
time_slot_14_pm25=[]
time_slot_14_pm10=[]
time_slot_15_pm1=[]
time_slot_15_pm25=[]
time_slot_15_pm10=[]
time_slot_16_pm1=[]
time_slot_16_pm25=[]
time_slot_16_pm10=[]
time_slot_17_pm1=[]
time_slot_17_pm25=[]
time_slot_17_pm10=[]
time_slot_18_pm1=[]
time_slot_18_pm25=[]
time_slot_18_pm10=[]
time_slot_19_pm1=[]
time_slot_19_pm25=[]
time_slot_19_pm10=[]
time_slot_20_pm1=[]
time_slot_20_pm25=[]
time_slot_20_pm10=[]
time_slot_21_pm1=[]
time_slot_21_pm25=[]
time_slot_21_pm10=[]
time_slot_22_pm1=[]
time_slot_22_pm25=[]
time_slot_22_pm10=[]
time_slot_23_pm1=[]
time_slot_23_pm25=[]
time_slot_23_pm10=[]
time_slot_24_pm1=[]
time_slot_24_pm25=[]
time_slot_24_pm10=[]

for rows in csv_data:
    if current_date == rows[0]:
        # print("current date matches -> ",current_date)
        csv_time = rows[1]
        time_slot = fun_time_slot(csv_time)
        slot_no = time_slot
        # print(time_slot," -> ",csv_time," -> ", current_date)
        # add to the respective slot list
        if time_slot=="SLOT-1":
            time_slot_1_pm1.append((float)(rows[2]))
            time_slot_1_pm25.append((float)(rows[3]))
            time_slot_1_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-2":
            time_slot_2_pm1.append((float)(rows[2]))
            time_slot_2_pm25.append((float)(rows[3]))
            time_slot_2_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-3":
            time_slot_3_pm1.append((float)(rows[2]))
            time_slot_3_pm25.append((float)(rows[3]))
            time_slot_3_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-4":
            time_slot_4_pm1.append((float)(rows[2]))
            time_slot_4_pm25.append((float)(rows[3]))
            time_slot_4_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-5":
            time_slot_5_pm1.append((float)(rows[2]))
            time_slot_5_pm25.append((float)(rows[3]))
            time_slot_5_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-6":
            time_slot_6_pm1.append((float)(rows[2]))
            time_slot_6_pm25.append((float)(rows[3]))
            time_slot_6_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-7":
            time_slot_7_pm1.append((float)(rows[2]))
            time_slot_7_pm25.append((float)(rows[3]))
            time_slot_7_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-8":
            time_slot_8_pm1.append((float)(rows[2]))
            time_slot_8_pm25.append((float)(rows[3]))
            time_slot_8_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-9":
            time_slot_9_pm1.append((float)(rows[2]))
            time_slot_9_pm25.append((float)(rows[3]))
            time_slot_9_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-10":
            time_slot_10_pm1.append((float)(rows[2]))
            time_slot_10_pm25.append((float)(rows[3]))
            time_slot_10_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-11":
            time_slot_11_pm1.append((float)(rows[2]))
            time_slot_11_pm25.append((float)(rows[3]))
            time_slot_11_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-12":
            time_slot_12_pm1.append((float)(rows[2]))
            time_slot_12_pm25.append((float)(rows[3]))
            time_slot_12_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-13":
            time_slot_13_pm1.append((float)(rows[2]))
            time_slot_13_pm25.append((float)(rows[3]))
            time_slot_13_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-14":
            time_slot_14_pm1.append((float)(rows[2]))
            time_slot_14_pm25.append((float)(rows[3]))
            time_slot_14_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-15":
            time_slot_15_pm1.append((float)(rows[2]))
            time_slot_15_pm25.append((float)(rows[3]))
            time_slot_15_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-16":
            time_slot_16_pm1.append((float)(rows[2]))
            time_slot_16_pm25.append((float)(rows[3]))
            time_slot_16_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-17":
            time_slot_17_pm1.append((float)(rows[2]))
            time_slot_17_pm25.append((float)(rows[3]))
            time_slot_17_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-18":
            time_slot_18_pm1.append((float)(rows[2]))
            time_slot_18_pm25.append((float)(rows[3]))
            time_slot_18_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-19":
            time_slot_19_pm1.append((float)(rows[2]))
            time_slot_19_pm25.append((float)(rows[3]))
            time_slot_19_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-20":
            time_slot_20_pm1.append((float)(rows[2]))
            time_slot_20_pm25.append((float)(rows[3]))
            time_slot_20_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-21":
            time_slot_21_pm1.append((float)(rows[2]))
            time_slot_21_pm25.append((float)(rows[3]))
            time_slot_21_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-22":
            time_slot_22_pm1.append((float)(rows[2]))
            time_slot_22_pm25.append((float)(rows[3]))
            time_slot_22_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-23":
            time_slot_23_pm1.append((float)(rows[2]))
            time_slot_23_pm25.append((float)(rows[3]))
            time_slot_23_pm10.append((float)(rows[4]))
        elif time_slot=="SLOT-24":
            time_slot_24_pm1.append((float)(rows[2]))
            time_slot_24_pm25.append((float)(rows[3]))
            time_slot_24_pm10.append((float)(rows[4]))
        
    else:
        # calculate the avg for 24 slots and add it to the list
        mean_slot1_pm1=0
        mean_slot1_pm25=0
        mean_slot1_pm10=0
        mean_slot2_pm1=0
        mean_slot2_pm25=0
        mean_slot2_pm10=0
        mean_slot3_pm1=0
        mean_slot3_pm25=0
        mean_slot3_pm10=0
        mean_slot4_pm1=0
        mean_slot4_pm25=0
        mean_slot4_pm10=0
        mean_slot5_pm1=0
        mean_slot5_pm25=0
        mean_slot5_pm10=0
        mean_slot6_pm1=0
        mean_slot6_pm25=0
        mean_slot6_pm10=0
        mean_slot7_pm1=0
        mean_slot7_pm25=0
        mean_slot7_pm10=0
        mean_slot8_pm1=0
        mean_slot8_pm25=0
        mean_slot8_pm10=0
        mean_slot9_pm1=0
        mean_slot9_pm25=0
        mean_slot9_pm10=0
        mean_slot10_pm1=0
        mean_slot10_pm25=0
        mean_slot10_pm10=0
        mean_slot11_pm1=0
        mean_slot11_pm25=0
        mean_slot11_pm10=0
        mean_slot12_pm1=0
        mean_slot12_pm25=0
        mean_slot12_pm10=0
        mean_slot13_pm1=0
        mean_slot13_pm25=0
        mean_slot13_pm10=0
        mean_slot14_pm1=0
        mean_slot14_pm25=0
        mean_slot14_pm10=0
        mean_slot15_pm1=0
        mean_slot15_pm25=0
        mean_slot15_pm10=0
        mean_slot16_pm1=0
        mean_slot16_pm25=0
        mean_slot16_pm10=0
        mean_slot17_pm1=0
        mean_slot17_pm25=0
        mean_slot17_pm10=0
        mean_slot18_pm1=0
        mean_slot18_pm25=0
        mean_slot18_pm10=0
        mean_slot19_pm1=0
        mean_slot19_pm25=0
        mean_slot19_pm10=0
        mean_slot20_pm1=0
        mean_slot20_pm25=0
        mean_slot20_pm10=0
        mean_slot21_pm1=0
        mean_slot21_pm25=0
        mean_slot21_pm10=0
        mean_slot22_pm1=0
        mean_slot22_pm25=0
        mean_slot22_pm10=0
        mean_slot23_pm1=0
        mean_slot23_pm25=0
        mean_slot23_pm10=0
        mean_slot24_pm1=0
        mean_slot24_pm25=0
        mean_slot24_pm10=0
        
        if len(time_slot_1_pm1)==0:
            mean_slot1_pm1=0
        else:
            mean_slot1_pm1 = sum(time_slot_1_pm1)/len(time_slot_1_pm1)
        if len(time_slot_1_pm25)==0:
            mean_slot1_pm25=0
        else:
            mean_slot1_pm25 = sum(time_slot_1_pm25)/len(time_slot_1_pm25)
        if len(time_slot_1_pm10)==0:
            mean_slot1_pm10=0
        else:
            mean_slot1_pm10 = sum(time_slot_1_pm10)/len(time_slot_1_pm10)
        
        
        if len(time_slot_2_pm1)==0:
            mean_slot2_pm1=0
        else:
            mean_slot2_pm1 = sum(time_slot_2_pm1)/len(time_slot_2_pm1)
        if len(time_slot_2_pm25)==0:
            mean_slot2_pm25=0
        else:
            mean_slot2_pm25 = sum(time_slot_2_pm25)/len(time_slot_2_pm25)
        if len(time_slot_2_pm10)==0:
            mean_slot2_pm10=0
        else:
            mean_slot2_pm10 = sum(time_slot_2_pm10)/len(time_slot_2_pm10)
        
        
        if len(time_slot_3_pm1)==0:
            mean_slot3_pm1=0
        else:
            mean_slot3_pm1 = sum(time_slot_3_pm1)/len(time_slot_3_pm1)
        if len(time_slot_3_pm25)==0:
            mean_slot3_pm25=0
        else:
            mean_slot3_pm25 = sum(time_slot_3_pm25)/len(time_slot_3_pm25)
        if len(time_slot_3_pm10)==0:
            mean_slot3_pm10=0
        else:
            mean_slot3_pm10 = sum(time_slot_3_pm10)/len(time_slot_3_pm10)
        
        if len(time_slot_4_pm1)==0:
            mean_slot4_pm1=0
        else:
            mean_slot4_pm1 = sum(time_slot_4_pm1)/len(time_slot_4_pm1)
        if len(time_slot_4_pm25)==0:
            mean_slot4_pm25=0
        else:
            mean_slot4_pm25 = sum(time_slot_4_pm25)/len(time_slot_4_pm25)
        if len(time_slot_4_pm10)==0:
            mean_slot4_pm10=0
        else:
            mean_slot4_pm10 = sum(time_slot_4_pm10)/len(time_slot_4_pm10)
            
        if len(time_slot_5_pm1)==0:
            mean_slot5_pm1=0
        else:
            mean_slot5_pm1 = sum(time_slot_5_pm1)/len(time_slot_5_pm1)
        if len(time_slot_5_pm25)==0:
            mean_slot5_pm25=0
        else:
            mean_slot5_pm25 = sum(time_slot_5_pm25)/len(time_slot_5_pm25)
        if len(time_slot_5_pm10)==0:
            mean_slot5_pm10=0
        else:
            mean_slot5_pm10 = sum(time_slot_5_pm10)/len(time_slot_5_pm10)
            
        if len(time_slot_6_pm1)==0:
            mean_slot6_pm1=0
        else:
            mean_slot6_pm1 = sum(time_slot_6_pm1)/len(time_slot_6_pm1)
        if len(time_slot_6_pm25)==0:
            mean_slot6_pm25=0
        else:
            mean_slot6_pm25 = sum(time_slot_6_pm25)/len(time_slot_6_pm25)
        if len(time_slot_6_pm10)==0:
            mean_slot6_pm10=0
        else:
            mean_slot6_pm10 = sum(time_slot_6_pm10)/len(time_slot_6_pm10)
            
        if len(time_slot_7_pm1)==0:
            mean_slot7_pm1=0
        else:
            mean_slot7_pm1 = sum(time_slot_7_pm1)/len(time_slot_7_pm1)
        if len(time_slot_7_pm25)==0:
            mean_slot7_pm25=0
        else:
            mean_slot7_pm25 = sum(time_slot_7_pm25)/len(time_slot_7_pm25)
        if len(time_slot_7_pm10)==0:
            mean_slot7_pm10=0
        else:
            mean_slot7_pm10 = sum(time_slot_7_pm10)/len(time_slot_7_pm10)
        
        if len(time_slot_8_pm1)==0:
            mean_slot8_pm1=0
        else:
            mean_slot8_pm1 = sum(time_slot_8_pm1)/len(time_slot_8_pm1)
        if len(time_slot_8_pm25)==0:
            mean_slot8_pm25=0
        else:
            mean_slot8_pm25 = sum(time_slot_8_pm25)/len(time_slot_8_pm25)
        if len(time_slot_8_pm10)==0:
            mean_slot8_pm10=0
        else:
            mean_slot8_pm10 = sum(time_slot_8_pm10)/len(time_slot_8_pm10)
            
        if len(time_slot_9_pm1)==0:
            mean_slot9_pm1=0
        else:
            mean_slot9_pm1 = sum(time_slot_9_pm1)/len(time_slot_9_pm1)
        if len(time_slot_9_pm25)==0:
            mean_slot9_pm25=0
        else:
            mean_slot9_pm25 = sum(time_slot_9_pm25)/len(time_slot_9_pm25)
        if len(time_slot_9_pm10)==0:
            mean_slot9_pm10=0
        else:
            mean_slot9_pm10 = sum(time_slot_9_pm10)/len(time_slot_9_pm10)
            
        if len(time_slot_10_pm1)==0:
            mean_slot10_pm1=0
        else:
            mean_slot10_pm1 = sum(time_slot_10_pm1)/len(time_slot_10_pm1)
        if len(time_slot_10_pm25)==0:
            mean_slot10_pm25=0
        else:
            mean_slot10_pm25 = sum(time_slot_10_pm25)/len(time_slot_10_pm25)
        if len(time_slot_10_pm10)==0:
            mean_slot10_pm10=0
        else:
            mean_slot10_pm10 = sum(time_slot_10_pm10)/len(time_slot_10_pm10)
            
        if len(time_slot_11_pm1)==0:
            mean_slot11_pm1=0
        else:
            mean_slot11_pm1 = sum(time_slot_11_pm1)/len(time_slot_11_pm1)
        if len(time_slot_11_pm25)==0:
            mean_slot11_pm25=0
        else:
            mean_slot11_pm25 = sum(time_slot_11_pm25)/len(time_slot_11_pm25)
        if len(time_slot_11_pm10)==0:
            mean_slot11_pm10=0
        else:
            mean_slot11_pm10 = sum(time_slot_11_pm10)/len(time_slot_11_pm10)
            
        if len(time_slot_12_pm1)==0:
            mean_slot12_pm1=0
        else:
            mean_slot12_pm1 = sum(time_slot_12_pm1)/len(time_slot_12_pm1)
        if len(time_slot_12_pm25)==0:
            mean_slot12_pm25=0
        else:
            mean_slot12_pm25 = sum(time_slot_12_pm25)/len(time_slot_12_pm25)
        if len(time_slot_12_pm10)==0:
            mean_slot12_pm10=0
        else:
            mean_slot12_pm10 = sum(time_slot_12_pm10)/len(time_slot_12_pm10)
            
        if len(time_slot_13_pm1)==0:
            mean_slot13_pm1=0
        else:
            mean_slot13_pm1 = sum(time_slot_13_pm1)/len(time_slot_13_pm1)
        if len(time_slot_13_pm25)==0:
            mean_slot13_pm25=0
        else:
            mean_slot13_pm25 = sum(time_slot_13_pm25)/len(time_slot_13_pm25)
        if len(time_slot_13_pm10)==0:
            mean_slot13_pm10=0
        else:
            mean_slot13_pm10 = sum(time_slot_13_pm10)/len(time_slot_13_pm10)
            
        if len(time_slot_14_pm1)==0:
            mean_slot14_pm1=0
        else:
            mean_slot14_pm1 = sum(time_slot_14_pm1)/len(time_slot_14_pm1)
        if len(time_slot_14_pm25)==0:
            mean_slot14_pm25=0
        else:
            mean_slot14_pm25 = sum(time_slot_14_pm25)/len(time_slot_14_pm25)
        if len(time_slot_14_pm10)==0:
            mean_slot14_pm10=0
        else:
            mean_slot14_pm10 = sum(time_slot_14_pm10)/len(time_slot_14_pm10)
            
        if len(time_slot_15_pm1)==0:
            mean_slot15_pm1=0
        else:
            mean_slot15_pm1 = sum(time_slot_15_pm1)/len(time_slot_15_pm1)
        if len(time_slot_15_pm25)==0:
            mean_slot15_pm25=0
        else:
            mean_slot15_pm25 = sum(time_slot_15_pm25)/len(time_slot_15_pm25)
        if len(time_slot_15_pm10)==0:
            mean_slot15_pm10=0
        else:
            mean_slot15_pm10 = sum(time_slot_15_pm10)/len(time_slot_15_pm10)
            
        if len(time_slot_16_pm1)==0:
            mean_slot16_pm1=0
        else:
            mean_slot16_pm1 = sum(time_slot_16_pm1)/len(time_slot_16_pm1)
        if len(time_slot_16_pm25)==0:
            mean_slot16_pm25=0
        else:
            mean_slot16_pm25 = sum(time_slot_16_pm25)/len(time_slot_16_pm25)
        if len(time_slot_16_pm10)==0:
            mean_slot16_pm10=0
        else:
            mean_slot16_pm10 = sum(time_slot_16_pm10)/len(time_slot_16_pm10)
            
        if len(time_slot_17_pm1)==0:
            mean_slot17_pm1=0
        else:
            mean_slot17_pm1 = sum(time_slot_17_pm1)/len(time_slot_17_pm1)
        if len(time_slot_17_pm25)==0:
            mean_slot17_pm25=0
        else:
            mean_slot17_pm25 = sum(time_slot_17_pm25)/len(time_slot_17_pm25)
        if len(time_slot_17_pm10)==0:
            mean_slot17_pm10=0
        else:
            mean_slot17_pm10 = sum(time_slot_17_pm10)/len(time_slot_17_pm10)
            
        if len(time_slot_18_pm1)==0:
            mean_slot18_pm1=0
        else:
            mean_slot18_pm1 = sum(time_slot_18_pm1)/len(time_slot_18_pm1)
        if len(time_slot_18_pm25)==0:
            mean_slot18_pm25=0
        else:
            mean_slot18_pm25 = sum(time_slot_18_pm25)/len(time_slot_18_pm25)
        if len(time_slot_18_pm10)==0:
            mean_slot18_pm10=0
        else:
            mean_slot18_pm10 = sum(time_slot_18_pm10)/len(time_slot_18_pm10)
            
        if len(time_slot_19_pm1)==0:
            mean_slot19_pm1=0
        else:
            mean_slot19_pm1 = sum(time_slot_19_pm1)/len(time_slot_19_pm1)
        if len(time_slot_19_pm25)==0:
            mean_slot19_pm25=0
        else:
            mean_slot19_pm25 = sum(time_slot_19_pm25)/len(time_slot_19_pm25)
        if len(time_slot_19_pm10)==0:
            mean_slot19_pm10=0
        else:
            mean_slot19_pm10 = sum(time_slot_19_pm10)/len(time_slot_19_pm10)
            
        if len(time_slot_20_pm1)==0:
            mean_slot20_pm1=0
        else:
            mean_slot20_pm1 = sum(time_slot_20_pm1)/len(time_slot_20_pm1)
        if len(time_slot_20_pm25)==0:
            mean_slot20_pm25=0
        else:
            mean_slot20_pm25 = sum(time_slot_20_pm25)/len(time_slot_20_pm25)
        if len(time_slot_20_pm10)==0:
            mean_slot20_pm10=0
        else:
            mean_slot20_pm10 = sum(time_slot_20_pm10)/len(time_slot_20_pm10)
            
        if len(time_slot_21_pm1)==0:
            mean_slot21_pm1=0
        else:
            mean_slot21_pm1 = sum(time_slot_21_pm1)/len(time_slot_21_pm1)
        if len(time_slot_21_pm25)==0:
            mean_slot21_pm25=0
        else:
            mean_slot21_pm25 = sum(time_slot_21_pm25)/len(time_slot_21_pm25)
        if len(time_slot_21_pm10)==0:
            mean_slot21_pm10=0
        else:
            mean_slot21_pm10 = sum(time_slot_21_pm10)/len(time_slot_21_pm10)
            
        if len(time_slot_22_pm1)==0:
            mean_slot22_pm1=0
        else:
            mean_slot22_pm1 = sum(time_slot_22_pm1)/len(time_slot_22_pm1)
        if len(time_slot_22_pm25)==0:
            mean_slot22_pm25=0
        else:
            mean_slot22_pm25 = sum(time_slot_22_pm25)/len(time_slot_22_pm25)
        if len(time_slot_22_pm10)==0:
            mean_slot22_pm10=0
        else:
            mean_slot22_pm10 = sum(time_slot_22_pm10)/len(time_slot_22_pm10)
            
        if len(time_slot_23_pm1)==0:
            mean_slot23_pm1=0
        else:
            mean_slot23_pm1 = sum(time_slot_23_pm1)/len(time_slot_23_pm1)
        if len(time_slot_23_pm25)==0:
            mean_slot23_pm25=0
        else:
            mean_slot23_pm25 = sum(time_slot_23_pm25)/len(time_slot_23_pm25)
        if len(time_slot_23_pm10)==0:
            mean_slot23_pm10=0
        else:
            mean_slot23_pm10 = sum(time_slot_23_pm10)/len(time_slot_23_pm10)
            
        if len(time_slot_24_pm1)==0:
            mean_slot24_pm1=0
        else:
            mean_slot24_pm1 = sum(time_slot_24_pm1)/len(time_slot_24_pm1)
        if len(time_slot_24_pm25)==0:
            mean_slot24_pm25=0
        else:
            mean_slot24_pm25 = sum(time_slot_24_pm25)/len(time_slot_24_pm25)
        if len(time_slot_24_pm10)==0:
            mean_slot24_pm10=0
        else:
            mean_slot24_pm10 = sum(time_slot_24_pm10)/len(time_slot_24_pm10)
            
        slot_1_row_list = []
        slot_2_row_list = []
        slot_3_row_list = []
        slot_4_row_list = []
        slot_5_row_list = []
        slot_6_row_list = []
        slot_7_row_list = []
        slot_8_row_list = []
        slot_9_row_list = []
        slot_10_row_list = []
        slot_11_row_list = []
        slot_12_row_list = []
        slot_13_row_list = []
        slot_14_row_list = []
        slot_15_row_list = []
        slot_16_row_list = []
        slot_17_row_list = []
        slot_18_row_list = []
        slot_19_row_list = []
        slot_20_row_list = []
        slot_21_row_list = []
        slot_22_row_list = []
        slot_23_row_list = []
        slot_24_row_list = []

        slot_1_row_list.append(current_date)
        slot_1_row_list.append("SLOT-1")
        slot_1_row_list.append(mean_slot1_pm1)
        slot_1_row_list.append(mean_slot1_pm25)
        slot_1_row_list.append(mean_slot1_pm10)
        
        slot_2_row_list.append(current_date)
        slot_2_row_list.append("SLOT-2")
        slot_2_row_list.append(mean_slot2_pm1)
        slot_2_row_list.append(mean_slot2_pm25)
        slot_2_row_list.append(mean_slot2_pm10)
        
        slot_3_row_list.append(current_date)
        slot_3_row_list.append("SLOT-3")
        slot_3_row_list.append(mean_slot3_pm1)
        slot_3_row_list.append(mean_slot3_pm25)
        slot_3_row_list.append(mean_slot3_pm10)
        
        slot_4_row_list.append(current_date)
        slot_4_row_list.append("SLOT-4")
        slot_4_row_list.append(mean_slot4_pm1)
        slot_4_row_list.append(mean_slot4_pm25)
        slot_4_row_list.append(mean_slot4_pm10)
        
        slot_5_row_list.append(current_date)
        slot_5_row_list.append("SLOT-5")
        slot_5_row_list.append(mean_slot5_pm1)
        slot_5_row_list.append(mean_slot5_pm25)
        slot_5_row_list.append(mean_slot5_pm10)
        
        slot_6_row_list.append(current_date)
        slot_6_row_list.append("SLOT-6")
        slot_6_row_list.append(mean_slot6_pm1)
        slot_6_row_list.append(mean_slot6_pm25)
        slot_6_row_list.append(mean_slot6_pm10)
        
        slot_7_row_list.append(current_date)
        slot_7_row_list.append("SLOT-7")
        slot_7_row_list.append(mean_slot7_pm1)
        slot_7_row_list.append(mean_slot7_pm25)
        slot_7_row_list.append(mean_slot7_pm10)
        
        slot_8_row_list.append(current_date)
        slot_8_row_list.append("SLOT-8")
        slot_8_row_list.append(mean_slot8_pm1)
        slot_8_row_list.append(mean_slot8_pm25)
        slot_8_row_list.append(mean_slot8_pm10)
        
        slot_9_row_list.append(current_date)
        slot_9_row_list.append("SLOT-9")
        slot_9_row_list.append(mean_slot9_pm1)
        slot_9_row_list.append(mean_slot9_pm25)
        slot_9_row_list.append(mean_slot9_pm10)
        
        slot_10_row_list.append(current_date)
        slot_10_row_list.append("SLOT-10")
        slot_10_row_list.append(mean_slot10_pm1)
        slot_10_row_list.append(mean_slot10_pm25)
        slot_10_row_list.append(mean_slot10_pm10)
        
        slot_11_row_list.append(current_date)
        slot_11_row_list.append("SLOT-11")
        slot_11_row_list.append(mean_slot11_pm1)
        slot_11_row_list.append(mean_slot11_pm25)
        slot_11_row_list.append(mean_slot11_pm10)
        
        slot_12_row_list.append(current_date)
        slot_12_row_list.append("SLOT-12")
        slot_12_row_list.append(mean_slot12_pm1)
        slot_12_row_list.append(mean_slot12_pm25)
        slot_12_row_list.append(mean_slot12_pm10)
        
        slot_13_row_list.append(current_date)
        slot_13_row_list.append("SLOT-13")
        slot_13_row_list.append(mean_slot13_pm1)
        slot_13_row_list.append(mean_slot13_pm25)
        slot_13_row_list.append(mean_slot13_pm10)
        
        slot_14_row_list.append(current_date)
        slot_14_row_list.append("SLOT-14")
        slot_14_row_list.append(mean_slot14_pm1)
        slot_14_row_list.append(mean_slot14_pm25)
        slot_14_row_list.append(mean_slot14_pm10)
        
        slot_15_row_list.append(current_date)
        slot_15_row_list.append("SLOT-15")
        slot_15_row_list.append(mean_slot15_pm1)
        slot_15_row_list.append(mean_slot15_pm25)
        slot_15_row_list.append(mean_slot15_pm10)
        
        slot_16_row_list.append(current_date)
        slot_16_row_list.append("SLOT-16")
        slot_16_row_list.append(mean_slot16_pm1)
        slot_16_row_list.append(mean_slot16_pm25)
        slot_16_row_list.append(mean_slot16_pm10)
        
        slot_17_row_list.append(current_date)
        slot_17_row_list.append("SLOT-17")
        slot_17_row_list.append(mean_slot17_pm1)
        slot_17_row_list.append(mean_slot17_pm25)
        slot_17_row_list.append(mean_slot17_pm10)
        
        slot_18_row_list.append(current_date)
        slot_18_row_list.append("SLOT-18")
        slot_18_row_list.append(mean_slot18_pm1)
        slot_18_row_list.append(mean_slot18_pm25)
        slot_18_row_list.append(mean_slot18_pm10)
        
        slot_19_row_list.append(current_date)
        slot_19_row_list.append("SLOT-19")
        slot_19_row_list.append(mean_slot19_pm1)
        slot_19_row_list.append(mean_slot19_pm25)
        slot_19_row_list.append(mean_slot19_pm10)
        
        slot_20_row_list.append(current_date)
        slot_20_row_list.append("SLOT-20")
        slot_20_row_list.append(mean_slot20_pm1)
        slot_20_row_list.append(mean_slot20_pm25)
        slot_20_row_list.append(mean_slot20_pm10)
        
        slot_21_row_list.append(current_date)
        slot_21_row_list.append("SLOT-21")
        slot_21_row_list.append(mean_slot21_pm1)
        slot_21_row_list.append(mean_slot21_pm25)
        slot_21_row_list.append(mean_slot21_pm10)
        
        slot_22_row_list.append(current_date)
        slot_22_row_list.append("SLOT-22")
        slot_22_row_list.append(mean_slot22_pm1)
        slot_22_row_list.append(mean_slot22_pm25)
        slot_22_row_list.append(mean_slot22_pm10)
        
        slot_23_row_list.append(current_date)
        slot_23_row_list.append("SLOT-22")
        slot_23_row_list.append(mean_slot22_pm1)
        slot_23_row_list.append(mean_slot22_pm25)
        slot_23_row_list.append(mean_slot22_pm10)
        
        slot_24_row_list.append(current_date)
        slot_24_row_list.append("SLOT-24")
        slot_24_row_list.append(mean_slot24_pm1)
        slot_24_row_list.append(mean_slot24_pm25)
        slot_24_row_list.append(mean_slot24_pm10)
        
        output_data.append(slot_1_row_list)
        output_data.append(slot_2_row_list)
        output_data.append(slot_3_row_list)
        output_data.append(slot_4_row_list)
        output_data.append(slot_5_row_list)
        output_data.append(slot_6_row_list)
        output_data.append(slot_7_row_list)
        output_data.append(slot_8_row_list)
        output_data.append(slot_9_row_list)
        output_data.append(slot_10_row_list)
        output_data.append(slot_11_row_list)
        output_data.append(slot_12_row_list)
        output_data.append(slot_13_row_list)
        output_data.append(slot_14_row_list)
        output_data.append(slot_15_row_list)
        output_data.append(slot_16_row_list)
        output_data.append(slot_17_row_list)
        output_data.append(slot_18_row_list)
        output_data.append(slot_19_row_list)
        output_data.append(slot_20_row_list)
        output_data.append(slot_21_row_list)
        output_data.append(slot_22_row_list)
        output_data.append(slot_23_row_list)
        output_data.append(slot_24_row_list)
        
        slot_1_row_list = []
        slot_2_row_list = []
        slot_3_row_list = []
        slot_4_row_list = []
        slot_5_row_list = []
        slot_6_row_list = []
        slot_7_row_list = []
        slot_8_row_list = []
        slot_9_row_list = []
        slot_10_row_list = []
        slot_11_row_list = []
        slot_12_row_list = []
        slot_13_row_list = []
        slot_14_row_list = []
        slot_15_row_list = []
        slot_16_row_list = []
        slot_17_row_list = []
        slot_18_row_list = []
        slot_19_row_list = []
        slot_20_row_list = []
        slot_21_row_list = []
        slot_22_row_list = []
        slot_23_row_list = []
        slot_24_row_list = []
        
        
        # empty the mean list for the 24 slots
        time_slot_1_pm1=[]
        time_slot_1_pm25=[]
        time_slot_1_pm10=[]
        time_slot_2_pm1=[]
        time_slot_2_pm25=[]
        time_slot_2_pm10=[]
        time_slot_3_pm1=[]
        time_slot_3_pm25=[]
        time_slot_3_pm10=[]
        time_slot_4_pm1=[]
        time_slot_4_pm25=[]
        time_slot_4_pm10=[]
        time_slot_5_pm1=[]
        time_slot_5_pm25=[]
        time_slot_5_pm10=[]
        time_slot_6_pm1=[]
        time_slot_6_pm25=[]
        time_slot_6_pm10=[]
        time_slot_7_pm1=[]
        time_slot_7_pm25=[]
        time_slot_7_pm10=[]
        time_slot_8_pm1=[]
        time_slot_8_pm25=[]
        time_slot_8_pm10=[]
        time_slot_9_pm1=[]
        time_slot_9_pm25=[]
        time_slot_9_pm10=[]
        time_slot_10_pm1=[]
        time_slot_10_pm25=[]
        time_slot_10_pm10=[]
        time_slot_11_pm1=[]
        time_slot_11_pm25=[]
        time_slot_11_pm10=[]
        time_slot_12_pm1=[]
        time_slot_12_pm25=[]
        time_slot_12_pm10=[]
        time_slot_13_pm1=[]
        time_slot_13_pm25=[]
        time_slot_13_pm10=[]
        time_slot_14_pm1=[]
        time_slot_14_pm25=[]
        time_slot_14_pm10=[]
        time_slot_15_pm1=[]
        time_slot_15_pm25=[]
        time_slot_15_pm10=[]
        time_slot_16_pm1=[]
        time_slot_16_pm25=[]
        time_slot_16_pm10=[]
        time_slot_17_pm1=[]
        time_slot_17_pm25=[]
        time_slot_17_pm10=[]
        time_slot_18_pm1=[]
        time_slot_18_pm25=[]
        time_slot_18_pm10=[]
        time_slot_19_pm1=[]
        time_slot_19_pm25=[]
        time_slot_19_pm10=[]
        time_slot_20_pm1=[]
        time_slot_20_pm25=[]
        time_slot_20_pm10=[]
        time_slot_21_pm1=[]
        time_slot_21_pm25=[]
        time_slot_21_pm10=[]
        time_slot_22_pm1=[]
        time_slot_22_pm25=[]
        time_slot_22_pm10=[]
        time_slot_23_pm1=[]
        time_slot_23_pm25=[]
        time_slot_23_pm10=[]
        time_slot_24_pm1=[]
        time_slot_24_pm25=[]
        time_slot_24_pm10=[]
        
        current_date = rows[0]
        time_slot = fun_time_slot(csv_time)
        if time_slot=="SLOT-1":
            time_slot_1_pm1.append((float)(rows[2]))
            time_slot_1_pm25.append((float)(rows[3]))
            time_slot_1_pm10.append((float)(rows[4]))
        # add to list
        
with open("C:/Users/Swadesh Choudhary/Desktop/BTP/Average Code/alphasense data.csv","w",newline="") as write_obj:  
            csv_writer = writer(write_obj)
            csv_writer.writerows(output_data)
            print(" Successuflly Completed")
            write_obj.close()
# Out:
# removing empty rows ->  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-648dca6b34d6> in <module>
#     178         # print("current date matches -> ",current_date)
#     179         csv_time = rows[1]
# --> 180         time_slot = fun_time_slot(csv_time)
#     181         slot_no = time_slot
#     182         # print(time_slot," -> ",csv_time," -> ", current_date)
#
# <ipython-input-3-648dca6b34d6> in fun_time_slot(csv_time)
#      29         # print(csv_time_ls[0])
#      30     #print(csv_time_ls)
# ---> 31     if datetime.time(0,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(1,0):
#      32         return "SLOT-1"
#      33     elif datetime.time(1,0)<= datetime.time((int)(csv_time_ls[0]),0) < datetime.time(2,0):
#
# ValueError: invalid literal for int() with base 10: 'SL'
